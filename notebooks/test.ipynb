# %%
import os

# %%
from src.module.database import oracle_import
oracle_import("select * from dual")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 from src.module.database import oracle_import
# ----> 2 oracle_import("select * from dual")
#
# File /workspaces/machine-learning-playground-ochiroo/src/module/helper.py:55, in logging_timer.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#      52     logger_.log(level, f"Entering '{name}' -----> ")
#      54 start_time = time.time()
# ---> 55 result = func(*args, **kwargs)
#      56 elapsed_dur = elapsed_time(time.time() - start_time)
#      57 logger_.log(level, f'Function {func.__name__} executed in: {elapsed_dur}')
#
# File /workspaces/machine-learning-playground-ochiroo/src/module/database.py:79, in oracle_import(query)
#      76 @logging_timer()
#      77 def oracle_import(query):
#      78     """Import from oracle DB"""
# ...

# %%
path = os.path.expanduser("~/shared")

# %%
os.listdir(path)
# Out:
# ['data', 'README.md', 'models', 'reports', 'results']
